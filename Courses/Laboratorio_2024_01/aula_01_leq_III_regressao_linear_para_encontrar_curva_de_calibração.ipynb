# %% [markdown]
# <a href="https://colab.research.google.com/github/ucfilho/Biochemical_Engineering/blob/master/Courses/Laboratorio_2024_01/aula_01_leq_III_regressao_linear_para_encontrar_curva_de_calibra%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt

# %%
x = [0.1,0.2,0.4,0.5]
y = [0.2,0.6,1.5,2.0] # y = 2x+1
xlabel = 'Absorbancia 540nm'
ylabel = 'Concentracao (g/L)'

# %%
#add constant to predictor variables
x_ols = sm.add_constant(x)

#fit linear regression model
model = sm.OLS(y, x_ols).fit()

#view model summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.998
# Method:                 Least Squares   F-statistic:                     1620.
# Date:                Tue, 28 May 2024   Prob (F-statistic):           0.000617
# Time:                        15:33:00   Log-Likelihood:                 9.0798
# No. Observations:                   4   AIC:                            -14.16
# Df Residuals:                       2   BIC:                            -15.39
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.2750      0.038     -7.253      0.018      -0.438      -0.112
# ...

# %%
predictions = model.predict(x_ols)
print(predictions)
# Out:
# [0.175 0.625 1.525 1.975]

# %%
plt.scatter(x, y)
plt.plot(x, predictions, 'r')
plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.show()
