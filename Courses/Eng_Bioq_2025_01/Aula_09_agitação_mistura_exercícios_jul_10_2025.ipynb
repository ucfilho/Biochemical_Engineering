# %% [markdown]
# <a href="https://colab.research.google.com/github/ucfilho/Biochemical_Engineering/blob/master/Courses/Eng_Bioq_2025_01/Aula_09_agita%C3%A7%C3%A3o_mistura_exerc%C3%ADcios_jul_10_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Engenharia Bioquímica II- Resolução Exercícios de Agitação e Mistura

# %% [markdown]
# ## Exemplo 1
# Calcule o gasto energético mensal associado a um reator de 600 m$^3$ considere N$_P$=1.68, $\rho$=1200 kg/m$^3$, $\mu$=0.001 kg/m.s e o custo de 1kWh vale $0.98. Considere as duas situações: Nrps =0.5 e Nrps =0.75

# %% [markdown]
# ## Exemplo 2
# Calcule o tempo de mistura para duas situações do exemplo 2. Considere N$_Q$=1.2 e a mesmas duas situações: Nrps =0.5 e Nrps =0.75

# %% [markdown]
# ## Exemplo 3
# Calcule o gasto energético associado a um reator de 1200 m$^3$ considere N$_P$=1.68, $\rho$=1200 kg/m$^3$, $\mu$=0.001 kg/m.s e o custo de 1kWh vale $0.98. Considere as duas situações: Nrps =0.5 e Nrps =0.75

# %% [markdown]
# ##Exemplo 4
#
# Referente a mistura de um reator de 600 m3 com um agitador do modelo 4PBT45 pede-se:
# <br/> a) dimensione o sistema de agiatação que atende o projeto caso Pot/vol ≤ 1 HP/m3 , Nrps ≥ 0.5 e tempo de mistura inferior a 7 min.
# <br/> b)  explique se o referido reator com este agitador pode ser utilizado como um fermentador com aeração
# <br/> c) calcule o valor a ser pago em energia para o consumo energético associado ao item a) para o custo de $ 1,30 por kWh
# <br/> Obs: considere que o fluido tem ρ = 1200 kg/m3 , µ= 0.001 Pa.s e os valores de potência de motores padronizadas vistas

# %% [markdown]
# **Motores Pot HP:** -pág 15 </br> 1/3,1/2,3/4,1 , 1 1/2,2 ,3 ,5,7 1
# 2
# , 10, 15, 20, 30, 40, 50, 75, 100, 125, 200, 300, 350, 400, 450,
# 500, 600, 700, 800, 900, 1000, 1250, 1500, 1750, 2000, 2250, 2500, 3000, 3500, 4000

# %% [markdown]
# **pág 16**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Exemplo 5

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **McCabe cap 9- Agitation and Mixing of liquids**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
